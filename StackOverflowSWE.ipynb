# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
# %matplotlib inline

#gather 

df = pd.read_csv('./survey_results_public.csv')
df2 = pd.read_csv('./survey_results_public.csv')
df
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# ...           ...                                                ...
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
#                     ProgramHobby         Country      University  \
# 0                      Yes, both   United States              No
# ...

# %%
#assess
print(df.isnull()['CareerSatisfaction'].mean())
# Out:
# 0.16922867372353673

# %%
#clean
count = 0
removed_cols = []
for i in list(df):
    if(df.isnull()[str(i)].mean() > .75):
        removed_cols.append(str(i))
        count = count + 1
print(removed_cols)
df.drop(removed_cols,inplace=True, axis = 1)
df
# Out:
# ['YearsCodedJobPast', 'WebDeveloperType', 'MobileDeveloperType', 'NonDeveloperType', 'ExCoderReturn', 'ExCoderNotForMe', 'ExCoderBalance', 'ExCoder10Years', 'ExCoderBelonged', 'ExCoderSkills', 'ExCoderWillNotCode', 'ExCoderActive', 'TimeAfterBootcamp', 'ExpectedSalary']
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# ...           ...                                                ...
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# ...

# %%
#clean
nanlist = df.columns[df.isna().any()].tolist()
for i in nanlist: 
    for index, row in df[[str(i)]].mode().iterrows():
        if(index == 0):
            for b in row:
                df[str(i)] = df[str(i)].fillna(b)
df
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# ...           ...                                                ...
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
#                     ProgramHobby         Country      University  \
# 0                      Yes, both   United States              No
# ...

# %%
# Out:
# array([    0,     1,     2, ..., 51389, 51390, 51391], dtype=int64)

# %%
df
# Out:
#        Respondent                                       Professional  \
# 0               0                                            Student
# 1               1                                            Student
# 2               2                             Professional developer
# 3               3  Professional non-developer who sometimes write...
# 4               4                             Professional developer
# ...           ...                                                ...
# 51387       51387                             Professional developer
# 51388       51388                                            Student
# 51389       51389                             Professional developer
# 51390       51390                             Professional developer
# 51391       51391  Professional non-developer who sometimes write...
#
#                     ProgramHobby         Country      University  \
# 0                      Yes, both   United States              No
# ...

# %%
#clean
X = []
y = []
for i in list(df):
    if(str(i) == 'CareerSatisfaction'):
        y.append(str(i))
    else:
        X.append(str(i))

# %%
#clean
le = LabelEncoder()
for i in X:
    label = le.fit_transform(df[str(i)])
    df[str(i)] = label
df
# Out:
#        Respondent  Professional  ProgramHobby  Country  University  \
# 0               0             3             3      189           1
# 1               1             3             3      188           2
# 2               2             1             3      188           1
# 3               3             2             3      189           1
# 4               4             1             2      173           1
# ...           ...           ...           ...      ...         ...
# 51387       51387             1             2      189           1
# 51388       51388             3             0      193           2
# 51389       51389             1             2       38           1
# 51390       51390             1             2      189           1
# 51391       51391             2             0       88           1
#
#        EmploymentStatus  FormalEducation  MajorUndergrad  HomeRemote  \
# 0                     4                7               8           0
# ...

# %%
df['JobSatisfaction']
# Out:
# 0         8
# 1         8
# 2         9
# 3         3
# 4         8
#          ..
# 51387     3
# 51388     8
# 51389    10
# 51390     7
# 51391     8
# Name: JobSatisfaction, Length: 51392, dtype: int64

# %%
df2['JobSatisfaction']
# Out:
# 0         NaN
# 1         NaN
# 2         9.0
# 3         3.0
# 4         8.0
#          ...
# 51387     3.0
# 51388     NaN
# 51389    10.0
# 51390     7.0
# 51391     8.0
# Name: JobSatisfaction, Length: 51392, dtype: float64

# %%
df['CareerSatisfaction']
# Out:
# 0         8.0
# 1         8.0
# 2         8.0
# 3         6.0
# 4         6.0
#          ...
# 51387     7.0
# 51388     8.0
# 51389    10.0
# 51390     6.0
# 51391     8.0
# Name: CareerSatisfaction, Length: 51392, dtype: float64

# %%
df2['CareerSatisfaction']
# Out:
# 0         NaN
# 1         NaN
# 2         8.0
# 3         6.0
# 4         6.0
#          ...
# 51387     7.0
# 51388     NaN
# 51389    10.0
# 51390     6.0
# 51391     8.0
# Name: CareerSatisfaction, Length: 51392, dtype: float64

# %%
from sklearn import svm
#analyze + model 
y = df[['CareerSatisfaction']]
X_train, X_test, y_train, y_test = train_test_split(df[X], y, test_size = .30, random_state=42) 

lm_model = LinearRegression(normalize=True) # Instantiate
lm_model.fit(X_train, y_train) 
y_test_preds = lm_model.predict(X_test)

# %%
#visualize
from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot
from scipy.stats import pearsonr

data1 = df[['StackOverflowSatisfaction']]
data2 = df[['FormalEducation']]
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data2), std(data2)))

corr, _ = pearsonr(data1, data2)
print(corr)

pyplot.scatter(data1, data2)
pyplot.show()
# Out:
# data1: mean=8.306 stdv=1.189
# data2: mean=3.229 stdv=3.172
# [-0.02084369]

# %%
import matplotlib.pyplot as plt
rng = np.random.RandomState(10)  # deterministic random data
a = np.hstack((rng.normal(size=1000),
rng.normal(loc=5, scale=2, size=1000)))
_ = plt.hist(df['JobSatisfaction'], bins='auto')  # arguments are passed to np.histogram
plt.title("Job Satisfaction")
plt.show()

# %%
import matplotlib.pyplot as plt
a = np.hstack((rng.normal(size=1000),
rng.normal(loc=5, scale=2, size=1000)))
_ = plt.hist(df['StackOverflowSatisfaction'], bins='auto')  # arguments are passed to np.histogram
plt.title("Stack Overflow Satisfaction")
plt.show()
# Out:
#   File "<ipython-input-52-6163c07167be>", line 3
#     _ = plt.hist(df['StackOverflowSatisfaction'], bins='auto')
#       ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
rng = np.random.RandomState(10)  # deterministic random data
a = np.hstack((rng.normal(size=1000),
rng.normal(loc=5, scale=2, size=1000)))
_ = plt.hist(df['CareerSatisfaction'], bins='auto')  # arguments are passed to np.histogram
plt.title("Career Satisfaction")
plt.show()
